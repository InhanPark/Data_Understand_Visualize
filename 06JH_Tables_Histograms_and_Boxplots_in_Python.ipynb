# %%
import seaborn as sns # For plotting
import matplotlib.pyplot as plt # For showing plots

# seaborn 에서 제공하는 연습용 data set (restaurant tip)
tips_data = sns.load_dataset("tips")

# %%
# 먼저 data set 의 내용을 살펴보는것이 후속 analysis 에 중요하다.
# column name 등을 확인한다.
# 'head' method 를 사용하면 기본적으로 앞쪽 5개의 data 를 보여준다. 숫자를 넣으면 더 볼 수있다.
tips_data.head(8)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
# 기본 통계량을 확인해본다
tips_data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# histogram 을 그려서 각 column data 에 대해 감을 더 잡아봄
sns.histplot(tips_data["total_bill"], kde = False).set_title("Histogram of Total Bill");

# %%
sns.histplot(tips_data["tip"], kde = False).set_title("Histogram of Total Tip");

# %%
# 결재액(bill)이 많으면 tip 도 많을것으로 예상되나, 두 data 사이의 상관관계를 그려봄. Scatterplot 이 유용함
sns.scatterplot(x="total_bill", y="tip", data=tips_data);

# %%
# 남녀간에 차이가 있는지를 color code 로 그려서 확인해 볼수도 있음
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips_data);

# %%
# Box plot 의 장점은 data 5개만 있으면 그릴 수 있다는 것이다. Histogram 은 좀 더 많은 data 가 있어야 한다.
sns.boxplot(x=tips_data["total_bill"]).set_title("Box plot of the Total Bill");

# %%
sns.boxplot(x=tips_data["tip"]).set_title("Box plot of the Tip")
# Out:
# Text(0.5, 1.0, 'Box plot of the Tip')

# %%
# Boxplot 을 한번에 여러개 그리기
sns.boxplot(x = tips_data["tip"], y = tips_data["smoker"])
# Out:
# <Axes: xlabel='tip', ylabel='smoker'>

# %%
sns.boxplot(x = tips_data["tip"], y = tips_data["time"])
# Out:
# <Axes: xlabel='tip', ylabel='time'>

# %%
# Histogram 을 한번에 여러개 그리기
g = sns.FacetGrid(tips_data, row = "time")
g = g.map(plt.hist, "tip")
plt.show()

# %%
sns.boxplot(x = tips_data["tip"], y = tips_data["day"])
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
g = sns.FacetGrid(tips_data, row = "day")
g = g.map(plt.hist, "tip")
plt.show()
